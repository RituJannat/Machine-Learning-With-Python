# %%
a=10
b=7
if a<b: print('a is less than b')
    
if a>b: print('a is greater than b')
# Out:
# a is greater than b

# %%
print(a<b)
print(a>b)
# Out:
# False
# True

# %%
if a<b: print("a is less than b")
else: print("a is greater than b")
# Out:
# a is greater than b

# %%
age = 19
if age<21: print("eligible for voting")
else: print("Not eligible for voting")
# Out:
# eligible for voting

# %%
mark = [45,46,48,60]
for m in marks:
    if m < 40:
        print(m, "Fail")
    else:
        print(m, "Pass")
# Out:
# 45 Pass
# 46 Pass
# 48 Pass
# 60 Pass

# %%
score = [101,105,208,100,30,20]
for s in score:
    if s > 105:
        print(s,"you are pass")
    elif s == 105:
        print (s, "You are pass")
    else:
        print(s,"Your are fail")
# Out:
# 101 Your are fail
# 105 You are pass
# 208 you are pass
# 100 Your are fail
# 30 Your are fail
# 20 Your are fail

# %%
result =[205,202,108,199,299,61]
for r in result:
    if r >= 99:
        print (r, "you are pass")
    elif r ==99:
        print(r,"you are pass")
    elif r <= 30:
        print(r,"you are pass")
    else: 
        print(r,"you are fail")
# Out:
# 205 you are pass
# 202 you are pass
# 108 you are pass
# 199 you are pass
# 299 you are pass
# 61 you are fail
