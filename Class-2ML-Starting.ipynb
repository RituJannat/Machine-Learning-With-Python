# %%
import numpy 
print(numpy.__version__)

# %%
print("Hello Jannat") 
x=2
print(x)
# Out:
# Hello Jannat
# 2

# %%
y=3
z=y+x
print(z)

# %%
n= 5
m= n+z

print(m)

# %%
u=10
s=5
a=u*s
print(a)
# Out:
# 50
