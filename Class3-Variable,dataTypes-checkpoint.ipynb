# %%
#print("Something")
display(1+1)
print(1+2+2)
3+6
# Out:
# 2
# 5
# 9

# %%
name="Jannat"
print(name)
# Out:
# Jannat

# %%
x=10
print(x)
# Out:
# 10

# %%
#invalid syntax
1x=5
print(1x)
# Out:
#   Cell In[12], line 2
#     1x=5
#     ^
# SyntaxError: invalid decimal literal

# %%
x_1=14
print(x_1)
# Out:
# 14

# %%
#can't use reserve word
if=23
print(if)
# Out:
#   Cell In[14], line 2
#     if=23
#       ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### *Data Types*

# %%
m="Sentence"
print(m)
# Out:
# Sentence

# %%
"sentence"
# Out:
# 'sentence'

# %%
2+5
#comment
# Out:
# 7

# %%
'''multiple 
line 
string'''
# Out:
# 'multiple \nline \nstring'

# %%
print('''multiple 
line 
string''')
# Out:
# multiple
# line
# string

# %%
n=13
m=1.2
o=n*m
p=n/m
print(m+n)
print(o)
print(p)
# Out:
# 14.2
# 15.6
# 10.833333333333334

# %% [markdown]
# **boolean**

# %%
x=True
print(x)
# Out:
# True

# %%
True
# Out:
# True

# %% [markdown]
# **NoneType**

# %%
y = None
print(y)
# Out:
# None

# %% [markdown]
# ## primary Compound

# %% [markdown]
# **list**

# %%
list1=[1,2,3,4]
list2=[3,5,True,"a",None,list1,False]
print(list2)
# Out:
# [3, 5, True, 'a', None, [1, 2, 3, 4], False]

# %%
print(len (list2))
# Out:
# 7

# %% [markdown]
# ## Accessing list elements

# %%
list2[0]
# Out:
# 3

# %%
list1[3]
# Out:
# 4

# %%
list1[2]
# Out:
# 3

# %%
list2[0]
# Out:
# 3

# %%
list2[3]
# Out:
# 'a'

# %%
list2[0] = 8 #we can change value in list easily by this format, list

# %%
list2[0]
# Out:
# 8

# %% [markdown]
# ### Set

# %%
set1={1,2,3,4,4,5} #set use for store unique value

# %%
set1
# Out:
# {1, 2, 3, 4, 5}

# %%
set2= {1,2,2,4,5,6,'a',"false"} #unorder collection of data is called set
print(set2)
# Out:
# {1, 2, 'a', 4, 5, 6, 'false'}

# %%
set2[0] #set can't use index
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 set2[0] #set can't use index
#
# TypeError: 'set' object is not subscriptable

# %%
s={1,2,3}
print(s)
# Out:
# {1, 2, 3}

# %%
v={True,1}
print(v)
# Out:
# {True}

# %%
d={False,1,0}
print(d)
# Out:
# {False, 1}

# %%
b={False,0}
print(b)
# Out:
# {False}

# %% [markdown]
# **tuples**

# %%
#it also collection of data(tuple)

# %%
tuple1=(1,2,3,4,5)
print(tuple1)
# Out:
# (1, 2, 3, 4, 5)

# %%
tuple2=(2,2,4,3,7,'a',9) #tuple allow duplicate
print(tuple2)
# Out:
# (2, 2, 4, 3, 7, 'a', 9)

# %%
tuple1[1]
# Out:
# 2

# %%
tuple1[2] = 6 #tuple can't change item but we can change in list
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 tuple1[2] = 6
#
# TypeError: 'tuple' object does not support item assignment
